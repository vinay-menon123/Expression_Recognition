# %% [markdown]
# # SVM CLASSIFICATION

# %% [markdown]
# ### Converting FER2013 TO IMAGES

# %%
import numpy as np
import pandas as pd
import os
import argparse
import errno
import scipy.misc
import dlib
import cv2
import imageio
from skimage.feature import hog
import sys
sys.argv=['']
del sys
# initialization
image_height = 48
image_width = 48
window_size = 24
window_step = 6
ONE_HOT_ENCODING = False
SAVE_IMAGES = False
GET_LANDMARKS = False
GET_HOG_FEATURES = False
GET_HOG_WINDOWS_FEATURES = False
SELECTED_LABELS = []
IMAGES_PER_LABEL = 500
OUTPUT_FOLDER_NAME = "fer2013_features"

# parse arguments and initialize variables:
parser = argparse.ArgumentParser()
parser.add_argument("-j", "--jpg", default="no", help="save images as .jpg files")
parser.add_argument("-l", "--landmarks", default="yes", help="extract Dlib Face landmarks")
parser.add_argument("-ho", "--hog", default="yes", help="extract HOG features")
parser.add_argument("-hw", "--hog_windows", default="yes", help="extract HOG features from a sliding window")
parser.add_argument("-o", "--onehot", default="no", help="one hot encoding")
parser.add_argument("-e", "--expressions", default="0,1,2,3,4,5,6", help="choose the faciale expression you want to use: 0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral")
args = parser.parse_args()
if args.jpg == "yes":
    SAVE_IMAGES = True
if args.landmarks == "yes":
    GET_LANDMARKS = True
if args.hog == "yes":
    GET_HOG_FEATURES = True
if args.hog_windows == "yes":
    GET_HOG_WINDOWS_FEATURES = True
if args.onehot == "yes":
    ONE_HOT_ENCODING = True
if args.expressions != "":
    expressions  = args.expressions.split(",")
    for i in range(0,len(expressions)):
        label = int(expressions[i])
        if (label >=0 and label<=6 ):
            SELECTED_LABELS.append(label)
if SELECTED_LABELS == []:
    SELECTED_LABELS = [0,1,2,3,4,5,6]
print( str(len(SELECTED_LABELS)) + " expressions")

# loading Dlib predictor and preparing arrays:
print( "preparing")
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')
original_labels = [0, 1, 2, 3, 4, 5, 6]
new_labels = list(set(original_labels) & set(SELECTED_LABELS))
nb_images_per_label = list(np.zeros(len(new_labels), 'uint8'))
try:
    os.makedirs(OUTPUT_FOLDER_NAME)
except OSError as e:
    if e.errno == errno.EEXIST and os.path.isdir(OUTPUT_FOLDER_NAME):
        pass
    else:
        raise

def get_landmarks(image, rects):
    # this function have been copied from http://bit.ly/2cj7Fpq
    if len(rects) > 1:
        raise BaseException("TooManyFaces")
    if len(rects) == 0:
        raise BaseException("NoFaces")
    return np.matrix([[p.x, p.y] for p in predictor(image, rects[0]).parts()])

def get_new_label(label, one_hot_encoding=False):
    if one_hot_encoding:
        new_label = new_labels.index(label)
        label = list(np.zeros(len(new_labels), 'uint8'))
        label[new_label] = 1
        return label
    else:
        return new_labels.index(label)

def sliding_hog_windows(image):
    hog_windows = []
    for y in range(0, image_height, window_step):
        for x in range(0, image_width, window_step):
            window = image[y:y+window_size, x:x+window_size]
            hog_windows.extend(hog(window, orientations=8, pixels_per_cell=(8, 8),
                                            cells_per_block=(1, 1), visualize=False))
    return hog_windows

print( "importing csv file")
data = pd.read_csv('fer2013.csv')

for category in data['Usage'].unique():
    print( "converting set: " + category + "...")
    # create folder
    if not os.path.exists(category):
        try:
            os.makedirs(OUTPUT_FOLDER_NAME + '/' + category)
        except OSError as e:
            if e.errno == errno.EEXIST and os.path.isdir(OUTPUT_FOLDER_NAME):
               pass
            else:
                raise
    
    # get samples and labels of the actual category
    category_data = data[data['Usage'] == category]
    samples = category_data['pixels'].values
    labels = category_data['emotion'].values
    
    # get images and extract features
    images = []
    labels_list = []
    landmarks = []
    hog_features = []
    hog_images = []
    for i in range(len(samples)):
        try:
            if labels[i] in SELECTED_LABELS and nb_images_per_label[get_new_label(labels[i])] < IMAGES_PER_LABEL:
                image = np.fromstring(samples[i], dtype=int, sep=" ").reshape((image_height, image_width))
                images.append(image)
                if SAVE_IMAGES:
                    imageio.imwrite(category + '/' + str(i) + '.jpg', image)
                if GET_HOG_WINDOWS_FEATURES:
                    features = sliding_hog_windows(image)
                    f, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16),
                                            cells_per_block=(1, 1), visualize=True)
                    hog_features.append(features)
                    hog_images.append(hog_image)
                elif GET_HOG_FEATURES:
                    features, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16),
                                            cells_per_block=(1, 1), visualize=True)
                    hog_features.append(features)
                    hog_images.append(hog_image)
                if GET_LANDMARKS:
                    imageio.imwrite('temp.jpg', image)
                    image2 = cv2.imread('temp.jpg')
                    face_rects = [dlib.rectangle(left=1, top=1, right=47, bottom=47)]
                    face_landmarks = get_landmarks(image2, face_rects)
                    landmarks.append(face_landmarks)            
                labels_list.append(get_new_label(labels[i], one_hot_encoding=ONE_HOT_ENCODING))
                nb_images_per_label[get_new_label(labels[i])] += 1
        except Exception as e:
            print( "error in image: " + str(i) + " - " + str(e))

    np.save(OUTPUT_FOLDER_NAME + '/' + category + '/images.npy', images)
    if ONE_HOT_ENCODING:
        np.save(OUTPUT_FOLDER_NAME + '/' + category + '/labels.npy', labels_list)
    else:
        np.save(OUTPUT_FOLDER_NAME + '/' + category + '/labels.npy', labels_list)
    if GET_LANDMARKS:
        np.save(OUTPUT_FOLDER_NAME + '/' + category + '/landmarks.npy', landmarks)
    if GET_HOG_FEATURES or GET_HOG_WINDOWS_FEATURES:
        np.save(OUTPUT_FOLDER_NAME + '/' + category + '/hog_features.npy', hog_features)
        np.save(OUTPUT_FOLDER_NAME + '/' + category + '/hog_images.npy', hog_images)
# Out:
# 7 expressions
# preparing
# importing csv file
# Lossy conversion from int32 to uint8. Range [11, 210]. Convert image to uint8 prior to saving to suppress this warning.
# converting set: Training...
# Lossy conversion from int32 to uint8. Range [0, 219]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [12, 235]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 241]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [4, 199]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 250]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 234]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [9, 252]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [18, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [6, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [46, 254]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 218]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [18, 220]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [3, 200]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 237]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [2, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 241]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 217]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [9, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [1, 245]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [9, 239]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [7, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 222]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [23, 213]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [15, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [20, 250]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [4, 244]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [3, 246]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [5, 230]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [5, 241]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 225]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [13, 226]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [15, 208]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [1, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [19, 249]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [28, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [12, 223]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 211]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [18, 241]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [11, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 236]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [12, 249]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [22, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [9, 219]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [19, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [2, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 249]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [31, 216]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [17, 244]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [7, 223]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [31, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [17, 248]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [13, 237]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [20, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [5, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 238]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [4, 215]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 231]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [18, 240]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 248]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 245]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 250]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [3, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [11, 139]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 231]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 232]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [46, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [1, 253]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 239]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [48, 247]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [4, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 197]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 246]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [18, 233]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [5, 253]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [12, 95]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 251]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [14, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 222]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [62, 215]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 243]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 238]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 197]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [62, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 231]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [4, 244]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [32, 224]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [23, 247]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [22, 225]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [11, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 213]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 227]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [3, 233]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 201]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [31, 247]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [23, 230]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 201]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [1, 255]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [0, 243]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from int32 to uint8. Range [9, 255]. Convert image to uint8 prior to saving to suppress this warning.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Vscode\VIT_Code\4th_sem\ML-J Comp\SVM_Classification.ipynb Cell 3' in <module>
#     <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=128'>129</a>     imageio.imwrite(category + '/' + str(i) + '.jpg', image)
#     <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=129'>130</a> if GET_HOG_WINDOWS_FEATURES:
# --> <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=130'>131</a>     features = sliding_hog_windows(image)
#     <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=131'>132</a>     f, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16),
#     <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=132'>133</a>                             cells_per_block=(1, 1), visualize=True)
#     <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=133'>134</a>     hog_features.append(features)
#
# c:\Vscode\VIT_Code\4th_sem\ML-J Comp\SVM_Classification.ipynb Cell 3' in sliding_hog_windows(image)
#      <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=90'>91</a>     for x in range(0, image_width, window_step):
#      <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=91'>92</a>         window = image[y:y+window_size, x:x+window_size]
# ---> <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=92'>93</a>         hog_windows.extend(hog(window, orientations=8, pixels_per_cell=(8, 8),
#      <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=93'>94</a>                                         cells_per_block=(1, 1), visualize=False))
#      <a href='vscode-notebook-cell:/c%3A/Vscode/VIT_Code/4th_sem/ML-J%20Comp/SVM_Classification.ipynb#ch0000003?line=94'>95</a> return hog_windows
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\_shared\utils.py:338, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=334'>335</a> channel_axis = kwargs.get('channel_axis', None)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=336'>337</a> if channel_axis is None:
# --> <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=337'>338</a>     return func(*args, **kwargs)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=339'>340</a> # TODO: convert scalars to a tuple in anticipation of eventually
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=340'>341</a> #       supporting a tuple of channel axes. Right now, only an
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=341'>342</a> #       integer or a single-element tuple is supported, though.
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=342'>343</a> if np.isscalar(channel_axis):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\_shared\utils.py:293, in deprecate_multichannel_kwarg.__call__.<locals>.fixed_func(*args, **kwargs)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=289'>290</a>     kwargs['channel_axis'] = convert[kwargs.pop('multichannel')]
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=291'>292</a> # Call the function with the fixed arguments
# --> <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/_shared/utils.py?line=292'>293</a> return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\feature\_hog.py:238, in hog(image, orientations, pixels_per_cell, cells_per_block, block_norm, visualize, transform_sqrt, feature_vector, multichannel, channel_axis)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/feature/_hog.py?line=234'>235</a> g_row = g_row.astype(float, copy=False)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/feature/_hog.py?line=235'>236</a> g_col = g_col.astype(float, copy=False)
# --> <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/feature/_hog.py?line=237'>238</a> _hoghistogram.hog_histograms(g_col, g_row, c_col, c_row, s_col, s_row,
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/feature/_hog.py?line=238'>239</a>                              n_cells_col, n_cells_row,
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/feature/_hog.py?line=239'>240</a>                              orientations, orientation_histogram)
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/feature/_hog.py?line=241'>242</a> # now compute the histogram for each cell
#     <a href='file:///c%3A/Users/Admin/AppData/Local/Programs/Python/Python310/lib/site-packages/skimage/feature/_hog.py?line=242'>243</a> hog_image = None
#
# KeyboardInterrupt:

# %% [markdown]
# ### TRAINING THE MODEL

# %%
import time
import argparse
import os
import sys
if sys.version_info >= (3, 0):
        import _pickle as cPickle
else:
        import cPickle
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

from data_loader import load_data 
from parameters import DATASET, TRAINING, HYPERPARAMS

def train(epochs=HYPERPARAMS.epochs, random_state=HYPERPARAMS.random_state, 
          kernel="linear", decision_function=HYPERPARAMS.decision_function, gamma=HYPERPARAMS.gamma, train_model=True):

        print( "loading dataset " + DATASET.name + "...")
        if train_model:
                data, validation = load_data(validation=True)
        else:
                data, validation, test = load_data(validation=True, test=True)
        
        if train_model:
            # Training phase
            print( "building model...")
            model = SVC(random_state=random_state, max_iter=1000, kernel="linear", decision_function_shape=decision_function, gamma=gamma)

            print( "start training...")
            print( "--")
            print( "kernel: {}".format(kernel))
            print( "decision function: {} ".format(decision_function))
            print( "max epochs: {} ".format(epochs))
            print( "gamma: {} ".format(gamma))
            print( "--")
            print( "Training samples: {}".format(len(data['Y'])))
            print( "Validation samples: {}".format(len(validation['Y'])))
            print( "--")
            start_time = time.time()
            model.fit(data['X'], data['Y'])
            training_time = time.time() - start_time
            print( "training time = {0:.1f} sec".format(training_time))

            if TRAINING.save_model:
                print( "saving model...")
                with open(TRAINING.save_model_path, 'wb') as f:
                        cPickle.dump(model, f)

            print( "evaluating...")
            validation_accuracy = evaluate(model, validation['X'], validation['Y'])
            print( "  - validation accuracy = {0:.1f}".format(validation_accuracy*100))
            return validation_accuracy
        else:
            # Testing phase : load saved model and evaluate on test dataset
            print( "start evaluation...")
            print( "loading pretrained model...")
            if os.path.isfile(TRAINING.save_model_path):
                with open(TRAINING.save_model_path, 'rb') as f:
                        model = cPickle.load(f)
            else:
                print( "Error: file '{}' not found".format(TRAINING.save_model_path))
                exit()

            print( "--")
            print( "Validation samples: {}".format(len(validation['Y'])))
            print( "Test samples: {}".format(len(test['Y'])))
            print( "--")
            print( "evaluating...")
            start_time = time.time()
            validation_accuracy = evaluate(model, validation['X'],  validation['Y'])
            print( "  - validation accuracy = {0:.1f}".format(validation_accuracy*100))
            test_accuracy = evaluate(model, test['X'], test['Y'])
            print( "  - test accuracy = {0:.1f}".format(test_accuracy*100))
            print( "  - evalution time = {0:.1f} sec".format(time.time() - start_time))
           
            return test_accuracy

def evaluate(model, X, Y):
        predicted_Y = model.predict(X)
        accuracy = accuracy_score(Y, predicted_Y)
        return accuracy

train()
# Out:
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovr
# max epochs: 10000
# gamma: auto
# --
# Training samples: 3436
# Validation samples: 56
# --
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# training time = 26.8 sec
# saving model...
# evaluating...
#   - validation accuracy = 48.2
# 0.48214285714285715

# %% [markdown]
# ### Evaluating

# %%
train(train_model=False)
# Out:
# loading dataset Fer2013...
# start evaluation...
# loading pretrained model...
# --
# Validation samples: 56
# Test samples: 8
# --
# evaluating...
#   - validation accuracy = 48.2
#   - test accuracy = 62.5
#   - evalution time = 1.1 sec
# 0.625

# %% [markdown]
# ### Optimizing parameters

# %%
import time
import argparse
import pprint
import numpy as np 
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import sys
sys.argv=['']
del sys
from train import train
from parameters import HYPERPARAMS

# define the search space
fspace = {
    'decision_function': hp.choice('decision_function', ['ovr', 'ovo']),
    'gamma':  hp.uniform('gamma', 0.001, 0.01)
}

# parse arguments

max_evals = 15
current_eval = 1
train_history = []

def function_to_minimize(hyperparams, gamma='auto', decision_function='ovr'):
    decision_function = hyperparams['decision_function']
    gamma = hyperparams['gamma']
    global current_eval 
    global max_evals
    print( "#################################")
    print( "       Evaluation {} of {}".format(current_eval, max_evals))
    print( "#################################")
    start_time = time.time()
    try:
        accuracy = train(epochs=HYPERPARAMS.epochs_during_hyperopt, decision_function=decision_function, gamma=gamma)
        training_time = int(round(time.time() - start_time))
        current_eval += 1
        train_history.append({'accuracy':accuracy, 'decision_function':decision_function, 'gamma':gamma, 'time':training_time})
    except Exception as e:
        print( "#################################")
        print( "Exception during training: {}".format(str(e)))
        print( "Saving train history in train_history.npy")
        np.save("train_history.npy", train_history)
        exit()
    return {'loss': -accuracy, 'time': training_time, 'status': STATUS_OK}

# lunch the hyperparameters search
trials = Trials()
best_trial = fmin(fn=function_to_minimize, space=fspace, algo=tpe.suggest, max_evals=max_evals, trials=trials)

# get some additional information and print( the best parameters
for trial in trials.trials:
    if trial['misc']['vals']['decision_function'][0] == best_trial['decision_function'] and \
            trial['misc']['vals']['gamma'][0] == best_trial['gamma']:
        best_trial['accuracy'] = -trial['result']['loss'] * 100
        best_trial['time'] = trial['result']['time']
print( "#################################")
print( "      Best parameters found")
print( "#################################")         
pprint.pprint(best_trial)
print( "decision_function { 0: ovr, 1: ovo }")
print( "#################################")
# Out:
# #################################
#        Evaluation 1 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovo
# max epochs: 500
# gamma: 0.0016739795843434407
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 47.1 sec
# saving model...
#   0%|          | 0/15 [00:47<?, ?trial/s, best loss=?]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 50.0
# #################################
#        Evaluation 2 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovo
# max epochs: 500
# gamma: 0.004138237540360022
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 50.1 sec
# saving model...
#   7%|▋         | 1/15 [01:39<11:21, 48.71s/trial, best loss: -0.5]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 46.4
# #################################
#        Evaluation 3 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovr
# max epochs: 500
# gamma: 0.0055362761337059314
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 50.0 sec
# saving model...
#  13%|█▎        | 2/15 [02:30<10:54, 50.37s/trial, best loss: -0.5]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 46.4
# #################################
#        Evaluation 4 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovr
# max epochs: 500
# gamma: 0.007305865312012842
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 56.7 sec
# saving model...
#  20%|██        | 3/15 [03:28<10:09, 50.81s/trial, best loss: -0.5]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 42.9
# #################################
#        Evaluation 5 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovo
# max epochs: 500
# gamma: 0.0072563170275441015
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 63.6 sec
# saving model...
#  27%|██▋       | 4/15 [04:33<09:51, 53.76s/trial, best loss: -0.5]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 44.6
# #################################
#        Evaluation 6 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovr
# max epochs: 500
# gamma: 0.004445633664857374
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 59.7 sec
# saving model...
#  33%|███▎      | 5/15 [05:35<09:40, 58.02s/trial, best loss: -0.5]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 46.4
# #################################
#        Evaluation 7 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovo
# max epochs: 500
# gamma: 0.0014829412865233873
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 50.6 sec
# saving model...
#  40%|████      | 6/15 [06:27<08:53, 59.23s/trial, best loss: -0.5]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 51.8
# #################################
#        Evaluation 8 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovo
# max epochs: 500
# gamma: 0.006008550679335149
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 59.2 sec
# saving model...
#  47%|████▋     | 7/15 [07:28<07:35, 56.98s/trial, best loss: -0.5178571428571429]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 42.9
# #################################
#        Evaluation 9 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovo
# max epochs: 500
# gamma: 0.005776520941865415
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 58.7 sec
# saving model...
#  53%|█████▎    | 8/15 [08:29<06:48, 58.31s/trial, best loss: -0.5178571428571429]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 44.6
# #################################
#        Evaluation 10 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovo
# max epochs: 500
# gamma: 0.005827477714065375
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 61.3 sec
# saving model...
#  60%|██████    | 9/15 [09:32<05:53, 58.98s/trial, best loss: -0.5178571428571429]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 44.6
# #################################
#        Evaluation 11 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovr
# max epochs: 500
# gamma: 0.0025636448452920277
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 53.2 sec
# saving model...
#  67%|██████▋   | 10/15 [10:27<05:01, 60.27s/trial, best loss: -0.5178571428571429]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 51.8
# #################################
#        Evaluation 12 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovr
# max epochs: 500
# gamma: 0.006436594043332757
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 59.2 sec
# saving model...
#  73%|███████▎  | 11/15 [11:28<03:54, 58.68s/trial, best loss: -0.5178571428571429]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 42.9
# #################################
#        Evaluation 13 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovr
# max epochs: 500
# gamma: 0.006691489636992653
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 61.0 sec
# saving model...
#  80%|████████  | 12/15 [12:31<02:58, 59.47s/trial, best loss: -0.5178571428571429]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 42.9
# #################################
#        Evaluation 14 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovr
# max epochs: 500
# gamma: 0.0015464144098602235
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 50.7 sec
# saving model...
#  87%|████████▋ | 13/15 [13:24<02:00, 60.47s/trial, best loss: -0.5178571428571429]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 51.8
# #################################
#        Evaluation 15 of 15
# #################################
# loading dataset Fer2013...
# building model...
# start training...
# --
# kernel: rbf
# decision function: ovo
# max epochs: 500
# gamma: 0.0026803362695825912
# --
# Training samples: 3436
# Validation samples: 56
# --
# training time = 52.5 sec
# saving model...
#  93%|█████████▎| 14/15 [14:18<00:58, 58.12s/trial, best loss: -0.5178571428571429]
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# evaluating...
#   - validation accuracy = 50.0
# 100%|██████████| 15/15 [14:20<00:00, 57.36s/trial, best loss: -0.5178571428571429]
# #################################
#       Best parameters found
# #################################
# {'accuracy': 51.78571428571429,
#  'decision_function': 1,
#  'gamma': 0.0014829412865233873,
#  'time': 52}
# decision_function { 0: ovr, 1: ovo }
# #################################

# %%
import numpy as np
data1 = np.load('C:/Vscode/VIT_Code/4th_sem/ML-J Comp/fer2013_features/PublicTest/hog_features.npy')
print("hog features",data1.shape)
data2 = np.load('C:/Vscode/VIT_Code/4th_sem/ML-J Comp/fer2013_features/PublicTest/hog_images.npy')
print("hog images",data2.shape)
data3 = np.load('C:/Vscode/VIT_Code/4th_sem/ML-J Comp/fer2013_features/PublicTest/images.npy')
print("images",data3.shape)
data4 = np.load('C:/Vscode/VIT_Code/4th_sem/ML-J Comp/fer2013_features/PublicTest/labels.npy')
print("labels",data4.shape)
data5 = np.load('C:/Vscode/VIT_Code/4th_sem/ML-J Comp/fer2013_features/PublicTest/landmarks.npy')
print("landmarks",data5.shape)
# Out:
# hog features (56, 2592)
# hog images (56, 48, 48)
# images (56, 48, 48)
# labels (56,)
# landmarks (56, 68, 2)
